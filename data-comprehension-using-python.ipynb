# %% [markdown]
# # Task 1

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import seaborn as sns
from pandas.plotting import parallel_coordinates
from pandas.plotting import scatter_matrix

# %% [markdown]
# ## Read the Iris Dataset

# %%
data = pd.read_csv("data\Iris.csv")

# %%
data.head(10)
# Out:
#    Sepal length  Sepal width  Petal length  Petal width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data['Species'].describe()
# Out:
# count        150
# unique         3
# top       Setosa
# freq          50
# Name: Species, dtype: object

# %% [markdown]
# ## Measurement of Central Tendency

# %%
data[['Petal width', 'Species']].head()
# Out:
#    Petal width Species
# 0          0.2  Setosa
# 1          0.2  Setosa
# 2          0.2  Setosa
# 3          0.2  Setosa
# 4          0.2  Setosa

# %% [markdown]
# ### Mean

# %%
data[data.Species == 'Setosa']['Petal width'].mean()
# Out:
# 0.2439999999999999

# %%
data[data.Species == 'Versicolor']['Petal width'].mean()
# Out:
# 1.3259999999999998

# %%
data[data.Species == 'Virginica']['Petal width'].mean()
# Out:
# 2.026

# %% [markdown]
# ### Median

# %%
data[data.Species == 'Setosa']['Petal width'].median()
# Out:
# 0.2

# %%
data[data.Species == 'Versicolor']['Petal width'].median()
# Out:
# 1.3

# %%
data[data.Species == 'Virginica']['Petal width'].median()
# Out:
# 2.0

# %% [markdown]
# ## Measures of Dispersion

# %% [markdown]
# ### Standards Deviation

# %%
import statistics

# %%
statistics.stdev(data[data.Species == 'Setosa']['Petal width'])
# Out:
# 0.10720950308167838

# %%
statistics.stdev(data[data.Species == 'Versicolor']['Petal width'])
# Out:
# 0.19775268000454405

# %%
statistics.stdev(data[data.Species == 'Virginica']['Petal width'])
# Out:
# 0.27465005563666733

# %% [markdown]
# ### Range

# %%
import numpy as np

# %%
q1, q3 = np.percentile(data[data.Species == 'Setosa']['Petal width'], [25,75])

# %%
q1
# Out:
# 0.2

# %%
q3
# Out:
# 0.3

# %%
iqr = q3 - q1
iqr
# Out:
# 0.09999999999999998

# %%
q1, q3 = np.percentile(data[data.Species == 'Versicolor']['Petal width'], [25,75])

# %%
q1
# Out:
# 1.2

# %%
q3
# Out:
# 1.5

# %%
iqr = q3 - q1
iqr
# Out:
# 0.30000000000000004

# %%
q1, q3 = np.percentile(data[data.Species == 'Virginica']['Petal width'], [25,75])

# %%
q1
# Out:
# 1.8

# %%
q3
# Out:
# 2.3

# %%
iqr = q3 - q1
iqr
# Out:
# 0.4999999999999998

# %% [markdown]
# # Task 2

# %% [markdown]
# ##### To identify which plot from the mentioned plotting types provides optimam values, first I have gone through all types of plotting to compare and justify the visualizations.

# %% [markdown]
# ## Line Chart

# %% [markdown]
# ##### Here I have seperated the species and plot line chart for each species with their feature values.

# %% [markdown]
# ##### From the line charts we can see that the lines for each features have been colored differently. We can also compare the feature values by the lines.

# %%
data[data.Species == 'Setosa']['Petal width'].plot()
data[data.Species == 'Versicolor']['Petal width'].plot()
data[data.Species == 'Virginica']['Petal width'].plot()
# Out:
# <AxesSubplot:>

# %%
data[data.Species == 'Setosa']['Sepal width'].plot()
data[data.Species == 'Versicolor']['Sepal width'].plot()
data[data.Species == 'Virginica']['Sepal width'].plot()
# Out:
# <AxesSubplot:>

# %%
data[data.Species == 'Setosa']['Petal length'].plot()
data[data.Species == 'Versicolor']['Petal length'].plot()
data[data.Species == 'Virginica']['Petal length'].plot()
# Out:
# <AxesSubplot:>

# %%
data[data.Species == 'Setosa']['Sepal length'].plot()
data[data.Species == 'Versicolor']['Sepal length'].plot()
data[data.Species == 'Virginica']['Sepal length'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# #####

# %%
set_df = data[data.Species == 'Setosa']
set_df = set_df.drop('Species', axis=1)

# %%
plt.figure(figsize=(8, 8))
x_pos = np.arange(len(set_df.columns))
plt.bar(x_pos, set_df.sum(), align='center')
plt.xticks(x_pos, set_df.columns)
plt.xlabel('Features', fontsize=18)
plt.ylabel('Values', fontsize=18)
plt.title('Setosa', fontsize=20)
plt.show()

# %%
ver_df = data[data.Species == 'Versicolor']
ver_df = ver_df.drop('Species', axis=1)

# %%
plt.figure(figsize=(8, 8))
x_pos = np.arange(len(ver_df.columns))
plt.bar(x_pos, ver_df.sum(), align='center')
plt.xticks(x_pos, ver_df.columns)
plt.xlabel('Features', fontsize=18)
plt.ylabel('Values', fontsize=18)
plt.title('Versicolor', fontsize=20)
plt.show()

# %%
vir_df = data[data.Species == 'Virginica']
vir_df = vir_df.drop('Species', axis=1)

# %%
plt.figure(figsize=(8, 8))
x_pos = np.arange(len(vir_df.columns))
plt.bar(x_pos, vir_df.sum(), align='center')
plt.xticks(x_pos, vir_df.columns)
plt.xlabel('Features', fontsize=18)
plt.ylabel('Values', fontsize=18)
plt.title('Virginica', fontsize=20)
plt.show()

# %% [markdown]
# ## Box Plot Chart

# %%
plt.figure(figsize = (8, 6))
plt.title('Setosa', fontsize=20)
set_df.boxplot()
# Out:
# <AxesSubplot:title={'center':'Setosa'}>

# %%
plt.figure(figsize = (8, 6))
plt.title('Versicolor', fontsize=20)
ver_df.boxplot()
# Out:
# <AxesSubplot:title={'center':'Versicolor'}>

# %%
plt.figure(figsize = (8, 6))
plt.title('Virginica', fontsize=20)
vir_df.boxplot()
# Out:
# <AxesSubplot:title={'center':'Virginica'}>

# %% [markdown]
# # Task 3

# %%
data.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# cols = data.columns.tolist()
# print(cols)

# %%
# Permute randomly the columns list of Iris flower dataset
# colsN = np.random.permutation(cols)
# colsN = colsN.tolist()
# print (colsN)

# %%
# Create a new version of Iris flower dataset with permutated columns
# dataN = data[colsN]
# dataN.head()

# %%
# Plot two parallel coordinates of Iris flower dataset with different ordering of the axis.
fig = plt.figure(figsize=(25,6))

ax1 = plt.subplot(121)
parallel_coordinates(data, 'Species',color=['r','g','b'])


# ax2= plt.subplot(122)
# parallel_coordinates(dataN, 'Species',color=['r','g','b'])


ax1.spines["left"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.spines["top"].set_visible(False)
#ax1.get_yaxis().tick_left() # remove unneeded ticks 

# ax2.spines["left"].set_visible(False)
# ax2.spines["bottom"].set_visible(False)
# ax2.spines["top"].set_visible(False)
#ax2.get_yaxis().tick_left() # remove unneeded ticks 

plt.tight_layout()
plt.show()
